# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import re
import nltk
stemmer=nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("twitter.csv")

# %%
data
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]

# %%
data["labels"]=data["class"].map({0: "hate_speech", 1:"Offiensive_language" , 2:"No Hate and Offensive"})
data.tail()
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                       labels
# 24778    Offiensive_language
# 24779  No Hate and Offensive
# 24780    Offiensive_language
# 24781    Offiensive_language
# 24782  No Hate and Offensive

# %%
data["class"].value_counts()
# Out:
# 1    19190
# 2     4163
# 0     1430
# Name: class, dtype: int64

# %%
data["labels"].value_counts()
# Out:
# Offiensive_language      19190
# No Hate and Offensive     4163
# hate_speech               1430
# Name: labels, dtype: int64

# %%
data=data[["tweet","labels"]]
data.tail()
# Out:
#                                                    tweet  \
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                       labels
# 24778    Offiensive_language
# 24779  No Hate and Offensive
# 24780    Offiensive_language
# 24781    Offiensive_language
# 24782  No Hate and Offensive

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stopword = set(stopwords.words('english'))
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
def dataclean(text):
    text=str(text).lower()
    text=re.sub('\[.*?\]','',text)
    text=re.sub('https?://\S+|www\.\S+','',text)
    text=re.sub('<.*?>+','',text)
    text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text=re.sub('\n','',text)
    text=re.sub('\w*\d\w*','',text)
    text=[word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text=[stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
data["tweet"]=data["tweet"].apply(dataclean)
data.head()
# Out:
# C:\Users\hitesh sonar\AppData\Local\Temp\ipykernel_11312\2136896521.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tweet"]=data["tweet"].apply(dataclean)
#                                                tweet                 labels
# 0   rt mayasolov woman shouldnt complain clean ho...  No Hate and Offensive
# 1   rt  boy dat coldtyga dwn bad cuffin dat hoe  ...    Offiensive_language
# 2   rt urkindofbrand dawg rt  ever fuck bitch sta...    Offiensive_language
# 3             rt cganderson vivabas look like tranni    Offiensive_language
# 4   rt shenikarobert shit hear might true might f...    Offiensive_language

# %%
data['labels'].value_counts()
# Out:
# Offiensive_language      19190
# No Hate and Offensive     4163
# hate_speech               1430
# Name: labels, dtype: int64

# %%
len(data)
# Out:
# 24783

# %%
cor=" "

for i in range(0,962):
    cor=cor+data["tweet"][i]

# %%
cor[301:4000]
# Out:
# 'x shit blow meclaim faith somebodi still fuck hoe brighterday sit hate anoth bitch  got much shit go caus im tire big bitch come us skinni  amp might get ya bitch back amp that  rhythmixx hobbi includ fight mariambitch keek bitch curv everyon  lol walk convers like smh murda gang bitch gang land  hoe smoke loser   yea  go ig bad bitch thing like  bitch get  bitch nigga miss  bitch plz whatev  bitch love  bitch get cut everyday b  black bottl amp bad bitch  broke bitch cant tell noth  cancel bitch like nino  cant see hoe wont chang  fuck bitch dont even suck dick   kermit video bout fuck ig got ya bitch tip toe hardwood floor    pussi lip like heaven door   hoe hit  met pussi ocean dr  gave pussi pill   need trippi bitch fuck hennessi  spend money want bitch busi  txt old bitch new bitch pussi wetter  id say im back old old bitch would get excit   aint bout murder game pussi nigga shut  your toe aint done pussi stink  im done bitter bitch wrap  angri bird there app  ya bitch  aint noth cut bitch  jus meet son ya mane ass bitch  shot lame cri hoe that tear clown  like snoop said  dont love hoe  momma said pussi cat insid doghous  hate hoe favorit   sevenon   nice girl bad make get naughti bad yello hoe real nice bodi south chick like em real thick  pimp pimp hoe  futur voic post pictur pussi get  like  pussi power drug   happyhumpday  quick piec pussi call drive  run round like brand new pussi that bout get fuck  bitch even worst theyll send guy  hoe like nigga spend money talk bout  dont trust nigga bitch  yall nigga b cuf hoe caus yall aint never bitch  dodg bullet    da bitch cut pregnant bound thank god  young pill chamberlain bitch love music  teanna trump probabl cleaner twitter hoe gay nigga couldnt wait act like bitch tonight ima steal cat n replac pitbul  rt  theparadox bitchamp hes gone alway hoeson bitch took tic tacsi like moviwanna get money fuck model bitch  russel simmon probabl  mind school much  deal bitch ass teacher retweet im fuck fag saidarizzleindacut femal think date pussi cute  stuff make pussi simplyaddictedtoguy  woof woof hot scalli ladadorebellaaa ya ever ask bitch bitch  kany voic yesadorezoey u gone bring ur side bitch game know ya gf friend   swearallaboutmanfeet  woof woof hot soleallyhaaaaa lemmi eat oreo amp dish one oreo lolalmightywayn jetsandaswish gook bitch fuck u  mayb youll get better almightywayn fuck red malon man bitch ass niggah could pleas use complet sentenc eggplant emoji doey say look like scream lmaoautoworid hennessey venom gt   that one sexi bitchbossbytchh seh pussi wetter shower curtainahmesehwetnessltlmao eaglesn everi eagl need see pic post bitch said racist shitbvsedchink yo fuck skateboard yall wood push faggot man ball life amjemiebennbabyanimalp babi monkey bathtim awwww soooo adorbaylaagottabodi  aint shit  damn skippi lolbeeasyjrizzi u ever kill ant sidewalk think damn nigga way get pussyno bs must b beenbasedb kudabrazyy   ring  mvps  bitch lolbeenflynsolo ppl talk bad ghettohood  kid grow nigga funnnnnnn bestproadvic fact tattoostattoo  hes pussi tattoo nippl  rt nelayden bitch want act like nigga bad  shit aint cuteeee nigga act like bitch get worship bitch  woof woofblackchiquitita wow rt thatmanpalm im lost buttcheek pierc  yeah shes hoeblacknerdjad ok sis shed rather broke bitch shrug shell tell work whalelookyher  queer gaywadbrokenpiecesmsc itsnotadam faggot read tweet dat k wasnt even funni lolbrosconfess bitch ungrat  fr  lulwhorcashandboobi kidnap yo bitch whitethunduh alsarabsss hes beaner smh tell hes mexicanccobey aydanmccoy happi birthday nig thank yochlldhoodruin ur teacher tell u u homework  bitch need go   nigga eat hoe lol hell yea lol john paul nigga sa'

# %%
data['tweet'][5000]
# Out:
# 'tielermlg psvch halfass come rescu retard lick dirti skidmark internet guy fucktard'

# %%
token=nltk.tokenize.RegexpTokenizer('\w+')

tok=token.tokenize(cor)

len(tok)
# Out:
# 7574

# %%
words=[]

for word in tok:
    words.append(word.lower())

# %%
stopwords = nltk.corpus.stopwords.words('english')

words_new = []

#Now we need to remove the stop words from the words variable
#Appending to words_new all words that are in words but not in sw

for word in words:
    if word not in stopwords:
        words_new.append(word)

# %%
len(words_new)
# Out:
# 7524

# %%
# Lemmatization

# %%
import nltk

# %%
from nltk.corpus import brown

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
nltk.data.path.append("")

# %%
from nltk.stem import WordNetLemmatizer 
  
wn = WordNetLemmatizer() 

lem_words=[]

for word in words_new:
    word=wn.lemmatize(word)
    lem_words.append(word)

# %%
len(lem_words)
# Out:
# 7524

# %%
same=0
diff=0

for i in range(0,1832):
    if(lem_words[i]==words_new[i]):
        same=same+1
    elif(lem_words[i]!=words_new[i]):
        diff=diff+1
        
print('Number of words Lemmatized=', diff)
print('Number of words not Lemmatized=', same)
# Out:
# Number of words Lemmatized= 30
# Number of words not Lemmatized= 1802

# %%
freq = nltk.FreqDist(lem_words)

# %%
plt.subplots(figsize=(20,12))
freq.plot(30)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
len(freq)
# Out:
# 3168

# %%
common=freq.most_common(50)

# %%
common
# Out:
# [('bitch', 343),
#  ('hoe', 127),
#  ('pussi', 116),
#  ('like', 91),
#  ('fuck', 83),
#  ('im', 69),
#  ('get', 69),
#  ('nigga', 64),
#  ('dont', 58),
#  ('rt', 52),
#  ('as', 51),
#  ('pornandroidiphoneipadsexxxx', 47),
#  ('u', 43),
#  ('love', 41),
#  ('got', 39),
#  ('aint', 38),
#  ('shit', 34),
#  ('amp', 31),
#  ('go', 29),
#  ('look', 26),
#  ('know', 26),
#  ('man', 25),
#  ('bad', 24),
#  ('still', 24),
#  ('one', 24),
#  ('want', 23),
#  ('make', 23),
#  ('call', 22),
#  ('ya', 21),
#  ('yall', 21),
#  ('yo', 21),
#  ('trash', 20),
#  ('cant', 20),
#  ('dick', 20),
#  ('girl', 20),
#  ('white', 20),
#  ('hate', 19),
#  ('back', 19),
#  ('bird', 19),
#  ('say', 18),
#  ('said', 18),
#  ('damn', 18),
#  ('lol', 17),
#  ('even', 17),
#  ('never', 17),
#  ('see', 16),
#  ('would', 16),
#  ('talk', 16),
#  ('scalli', 16),
#  ('eat', 16)]

# %%
data['labels'].value_counts()
# Out:
# Offiensive_language      19190
# No Hate and Offensive     4163
# hate_speech               1430
# Name: labels, dtype: int64

# %%
sns.countplot(x=data['labels'])
# Out:
# <Axes: xlabel='labels', ylabel='count'>

# %%
# worlwcould

# %%
res=' '.join([i for i in lem_words if not i.isdigit()])

# %%
import wordcloud

# %%
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=1000,
                          width=1400,
                          height=1200
                         ).generate(res)


plt.imshow(wordcloud)
plt.title('Resume Text WordCloud (100 Words)')
plt.axis('off')
plt.show()

# %%
plt.subplots(figsize=(20,15))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=200,
                          width=1400,
                          height=1200
                         ).generate(res)


plt.imshow(wordcloud)
plt.title('Resume Text WordCloud (200 Words)')
plt.axis('off')
plt.show()

# %%
# Build The Model

# %%
x=np.array(data['tweet'])
y=np.array(data['labels'])

cv=CountVectorizer()
X=cv.fit_transform(x)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
Clf=DecisionTreeClassifier()
Clf.fit(X_train,y_train)
Clf.score(X_test,y_test)
# Out:
# 0.87577943513877

# %%
user=input("Enter a Text: ")
data=cv.transform([user]).toarray()
output=Clf.predict(data)
print(output)
# Out:
# Enter a Text: good morning
# ['No Hate and Offensive']
